# %% [markdown]
# # Práctica Bases de Datos

# %% [markdown]
# ## Parte I: SQL Scape Room
# Por parejas, resuelve el misterio del asesinato en http://mystery.knightlab.com/

# %% [markdown]
# ## Parte II: Modelo Relacional

# %% [markdown]
# La empresa de venta de coches **KARLS** quiere crear un modelo de bases de datos. Para ello, nos ha compartido el fichero `ventas.csv`, que contiene sus ventas más recientes, con los siguientes campos:
#
# *	no_orden: número de la orden
# *	codigo_producto: código del producto comprado
# *	cantidad_orden: cantidad comprada
# *	precio_cada: precio de venta por unidad
# *	nombre_producto: nombre del producto
# *	linea_productos: línea de productos
# *	descr: descripción de la línea de productos
# *	precio_compra: precio de compra de cada producto al proveedor
# *	fecha_orden: fecha de la compra
# *	no_cliente: número del cliente
# *	nombre_cliente: nombre del cliente
# *	tlf: teléfono del cliente
# *	direccion: dirección del cliente
# *	ciudad: ciudad del cliente
# *	estado: estado o provincia del cliente
# *	codigo_postal: código postal del cliente
# *	pais: país del cliente
#
# Por otro lado, KARLS quiere conocer el idioma de cada cliente para poder realizar campañas de marketing personalizadas en diversos idiomas. Para conocer el idioma oficial de cada país, disponemos del acceso a una base de datos con los siguientes parámetros:
#
# *	Servidor: relational.fit.cvut.cz
# *	Usuario: guest
# *	Contraseña: relational
# *	Nombre de la base de datos: world
#
# ![imagen](https://relational.fit.cvut.cz/assets/img/datasets-generated/world.svg)

# %%
import sqlite3
import pymysql
import pandas as pd

# %%
# Mostramos los datos del .csv en pandas
datos = pd.read_csv('ventas.csv')
datos
# Out:
#       no_orden codigo_producto  cantidad_orden  precio_cada  \
# 0        10100        S18_1749              30       136.00
# 1        10100        S18_2248              50        55.09
# 2        10100        S18_4409              22        75.46
# 3        10100        S24_3969              49        35.29
# 4        10101        S18_2325              25       108.06
# ...        ...             ...             ...          ...
# 2991     10425        S24_2300              49       127.79
# 2992     10425        S24_2840              31        31.82
# 2993     10425        S32_1268              41        83.79
# 2994     10425        S32_2509              11        50.32
# 2995     10425        S50_1392              18        94.92
#
#                           nombre_producto   linea_productos  \
# 0                1917 Grand Touring Sedan      Vintage Cars
# 1                      1911 Ford Town Car      Vintage Cars
# 2     1932 Alfa Romeo 8C2300 Spider Sport      Vintage Cars
# 3        1936 Mercedes Benz 500k Roadster      Vintage Cars
# 4               1932 Model A Ford J-Coupe      Vintage Cars
# ...                                   ...               ...
# 2991             1962 Volkswagen Microbus  Trucks and Buses
# 2992  1958 Chevy Corvette Limited Edition      Classic Cars
# 2993          1980’s GM Manhattan Express  Trucks and Buses
# 2994          1954 Greyhound Scenicruiser  Trucks and Buses
# 2995     Diamond T620 Semi-Skirted Tanker  Trucks and Buses
#
#                                                   descr  precio_compra  \
# 0     Our Vintage Car models realistically portray a...          86.70
# 1     Our Vintage Car models realistically portray a...          33.30
# 2     Our Vintage Car models realistically portray a...          43.26
# 3     Our Vintage Car models realistically portray a...          21.75
# 4     Our Vintage Car models realistically portray a...          58.48
# ...                                                 ...            ...
# 2991  The Truck and Bus models are realistic replica...          61.34
# 2992  Attention car enthusiasts: Make your wildest c...          15.91
# 2993  The Truck and Bus models are realistic replica...          53.93
# 2994  The Truck and Bus models are realistic replica...          25.98
# 2995  The Truck and Bus models are realistic replica...          68.29
#
#      fecha_orden  no_cliente                nombre_cliente                tlf  \
# 0     2003-01-06         363  Online Diecast Creations Co.         6035558647
# 1     2003-01-06         363  Online Diecast Creations Co.         6035558647
# 2     2003-01-06         363  Online Diecast Creations Co.         6035558647
# 3     2003-01-06         363  Online Diecast Creations Co.         6035558647
# 4     2003-01-09         128          Blauer See Auto, Co.  +49 69 66 90 2555
# ...          ...         ...                           ...                ...
# 2991  2005-05-31         119             La Rochelle Gifts         40.67.8555
# 2992  2005-05-31         119             La Rochelle Gifts         40.67.8555
# 2993  2005-05-31         119             La Rochelle Gifts         40.67.8555
# 2994  2005-05-31         119             La Rochelle Gifts         40.67.8555
# 2995  2005-05-31         119             La Rochelle Gifts         40.67.8555
#
#                          direccion     ciudad estado codigo_postal     pais
# 0         2304 Long Airport Avenue     Nashua     NH         62005      USA
# 1         2304 Long Airport Avenue     Nashua     NH         62005      USA
# 2         2304 Long Airport Avenue     Nashua     NH         62005      USA
# 3         2304 Long Airport Avenue     Nashua     NH         62005      USA
# 4                    Lyonerstr. 34  Frankfurt    NaN         60528  Germany
# ...                            ...        ...    ...           ...      ...
# 2991  67, rue des Cinquante Otages     Nantes    NaN         44000   France
# 2992  67, rue des Cinquante Otages     Nantes    NaN         44000   France
# 2993  67, rue des Cinquante Otages     Nantes    NaN         44000   France
# 2994  67, rue des Cinquante Otages     Nantes    NaN         44000   France
# 2995  67, rue des Cinquante Otages     Nantes    NaN         44000   France
#
# [2996 rows x 17 columns]

# %% [markdown]
# Hay que pensar en las tablas de DIMENSIÓN y HECHOS

# %%
# Dimensión CLIENTE
cols = ['no_cliente', 'nombre_cliente', 'tlf', 'direccion', 'ciudad', 'estado', 'codigo_postal','pais']
cliente = datos[cols].drop_duplicates()
cliente
# Out:
#       no_cliente                      nombre_cliente                 tlf  \
# 0            363        Online Diecast Creations Co.          6035558647
# 4            128                Blauer See Auto, Co.   +49 69 66 90 2555
# 8            181                     Vitachrome Inc.          2125551500
# 10           121                  Baane Mini Imports          07-98 9555
# 26           141              Euro+ Shopping Channel      (91) 555 94 44
# ...          ...                                 ...                 ...
# 1619         204            Online Mini Collectables          6175557555
# 1650         249                  Amica Models & Co.         011-4988555
# 1708         299            NorwayGifts By Mail, Co.       +47 2212 1555
# 1721         286                Marta's Replicas Co.          6175558555
# 1813         415  Bavarian Collectables Imports, Co.   +49 89 61 08 9555
#
#                      direccion      ciudad estado codigo_postal     pais
# 0     2304 Long Airport Avenue      Nashua     NH         62005      USA
# 4                Lyonerstr. 34   Frankfurt    NaN         60528  Germany
# 8            2678 Kingston Rd.         NYC     NY         10022      USA
# 10      Erling Skakkes gate 78     Stavern    NaN          4110   Norway
# 26          C/ Moralzarzal, 86      Madrid    NaN         28034    Spain
# ...                        ...         ...    ...           ...      ...
# 1619        7635 Spinnaker Dr.  Brickhaven     MA         58339      USA
# 1650       Via Monte Bianco 34      Torino    NaN         10100    Italy
# 1708        Drammensveien 126A        Oslo    NaN        N 0106   Norway
# 1721       39323 Spinnaker Dr.   Cambridge     MA         51247      USA
# 1813              Hansastr. 15      Munich    NaN         80686  Germany
#
# [98 rows x 8 columns]

# %%
# Dimensión PRODUCTOS
cols = ['codigo_producto', 'nombre_producto','linea_productos','descr','precio_compra']
producto = datos[cols].drop_duplicates()
producto
# Out:
#     codigo_producto                      nombre_producto linea_productos  \
# 0          S18_1749             1917 Grand Touring Sedan    Vintage Cars
# 1          S18_2248                   1911 Ford Town Car    Vintage Cars
# 2          S18_4409  1932 Alfa Romeo 8C2300 Spider Sport    Vintage Cars
# 3          S24_3969     1936 Mercedes Benz 500k Roadster    Vintage Cars
# 4          S18_2325            1932 Model A Ford J-Coupe    Vintage Cars
# ..              ...                                  ...             ...
# 110        S24_1628            1966 Shelby Cobra 427 S/C    Classic Cars
# 113        S24_2766                   1949 Jaguar XK 120    Classic Cars
# 114        S24_2887                    1952 Citroen-15CV    Classic Cars
# 115        S24_3191            1969 Chevrolet Camaro Z28    Classic Cars
# 116        S24_3432                  2002 Chevy Corvette    Classic Cars
#
#                                                  descr  precio_compra
# 0    Our Vintage Car models realistically portray a...          86.70
# 1    Our Vintage Car models realistically portray a...          33.30
# 2    Our Vintage Car models realistically portray a...          43.26
# 3    Our Vintage Car models realistically portray a...          21.75
# 4    Our Vintage Car models realistically portray a...          58.48
# ..                                                 ...            ...
# 110  Attention car enthusiasts: Make your wildest c...          29.18
# 113  Attention car enthusiasts: Make your wildest c...          47.25
# 114  Attention car enthusiasts: Make your wildest c...          72.82
# 115  Attention car enthusiasts: Make your wildest c...          50.51
# 116  Attention car enthusiasts: Make your wildest c...          62.11
#
# [109 rows x 5 columns]

# %%
# TABLA DE HECHOS: COMPRAS
cols = ['no_orden', 'codigo_producto', 'cantidad_orden', 'precio_cada', 'fecha_orden','no_cliente']
compras = datos[cols].drop_duplicates()
compras
# Out:
#       no_orden codigo_producto  cantidad_orden  precio_cada fecha_orden  \
# 0        10100        S18_1749              30       136.00  2003-01-06
# 1        10100        S18_2248              50        55.09  2003-01-06
# 2        10100        S18_4409              22        75.46  2003-01-06
# 3        10100        S24_3969              49        35.29  2003-01-06
# 4        10101        S18_2325              25       108.06  2003-01-09
# ...        ...             ...             ...          ...         ...
# 2991     10425        S24_2300              49       127.79  2005-05-31
# 2992     10425        S24_2840              31        31.82  2005-05-31
# 2993     10425        S32_1268              41        83.79  2005-05-31
# 2994     10425        S32_2509              11        50.32  2005-05-31
# 2995     10425        S50_1392              18        94.92  2005-05-31
#
#       no_cliente
# 0            363
# 1            363
# 2            363
# 3            363
# 4            128
# ...          ...
# 2991         119
# 2992         119
# 2993         119
# 2994         119
# 2995         119
#
# [2996 rows x 6 columns]

# %% [markdown]
# Creamos una base de datos inicialmente vacía

# %%
conn = sqlite3.connect('karls.sqlite')

# %% [markdown]
# Guardamos nuestras tablas en la base de datos

# %%
cliente.to_sql('cliente', conn, index=False, if_exists='replace')

# %%
pd.read_sql('SELECT * FROM cliente', conn)
# Out:
#     no_cliente                      nombre_cliente                 tlf  \
# 0          363        Online Diecast Creations Co.          6035558647
# 1          128                Blauer See Auto, Co.   +49 69 66 90 2555
# 2          181                     Vitachrome Inc.          2125551500
# 3          121                  Baane Mini Imports          07-98 9555
# 4          141              Euro+ Shopping Channel      (91) 555 94 44
# ..         ...                                 ...                 ...
# 93         204            Online Mini Collectables          6175557555
# 94         249                  Amica Models & Co.         011-4988555
# 95         299            NorwayGifts By Mail, Co.       +47 2212 1555
# 96         286                Marta's Replicas Co.          6175558555
# 97         415  Bavarian Collectables Imports, Co.   +49 89 61 08 9555
#
#                    direccion      ciudad estado codigo_postal     pais
# 0   2304 Long Airport Avenue      Nashua     NH         62005      USA
# 1              Lyonerstr. 34   Frankfurt   None         60528  Germany
# 2          2678 Kingston Rd.         NYC     NY         10022      USA
# 3     Erling Skakkes gate 78     Stavern   None          4110   Norway
# 4         C/ Moralzarzal, 86      Madrid   None         28034    Spain
# ..                       ...         ...    ...           ...      ...
# 93        7635 Spinnaker Dr.  Brickhaven     MA         58339      USA
# 94       Via Monte Bianco 34      Torino   None         10100    Italy
# 95        Drammensveien 126A        Oslo   None        N 0106   Norway
# 96       39323 Spinnaker Dr.   Cambridge     MA         51247      USA
# 97              Hansastr. 15      Munich   None         80686  Germany
#
# [98 rows x 8 columns]

# %%
producto.to_sql('producto', conn, index=False, if_exists='replace')

# %%
compras.to_sql('compras', conn, index=False, if_exists='replace')

# %% [markdown]
# Nos conectamos a la base de datos world y añadimos la tabla que relacione cada cliente con su idioma

# %%
database_host = 'relational.fit.cvut.cz'
username = 'guest'
password = 'relational'
database_name = 'world'

db = pymysql.connect(database_host,username,password,database_name)

# %%
pd.read_sql('SHOW TABLES',db)
# Out:
#    Tables_in_world
# 0             City
# 1          Country
# 2  CountryLanguage

# %%
pd.read_sql('SELECT * FROM CountryLanguage', db)
# Out:
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]

# %%
# Query para saber el idioma más hablado de cada país 

query = '''
SELECT Name, Language, IsOfficial, Percentage

FROM CountryLanguage
JOIN Country
ON CountryLanguage.CountryCode = Country.Code

WHERE Percentage = (SELECT MAX(Percentage) 
                        FROM CountryLanguage
                        WHERE Country.Code = CountryLanguage.CountryCode
                    )
'''

idiomas = pd.read_sql(query, db)
idiomas
# Out:
#              Name        Language IsOfficial  Percentage
# 0           Aruba      Papiamento          F        76.7
# 1     Afghanistan          Pashto          T        52.4
# 2          Angola       Ovimbundu          F        37.2
# 3        Anguilla         English          T         0.0
# 4         Albania       Albaniana          T        97.9
# ..            ...             ...        ...         ...
# 236         Yemen          Arabic          T        99.6
# 237    Yugoslavia  Serbo-Croatian          T        75.2
# 238  South Africa            Zulu          T        22.7
# 239        Zambia           Bemba          F        29.7
# 240      Zimbabwe           Shona          F        72.1
#
# [241 rows x 4 columns]

# %%
idiomas.to_sql('idiomas', conn, index=False, if_exists='replace')

# %%
pd.read_sql('SELECT name FROM sqlite_master WHERE type="table"',conn)
# Out:
#               name
# 0          cliente
# 1         producto
# 2          compras
# 3  idiomas_cliente
# 4          idiomas

# %%
# Relacionar a cada cliente con su idioma
query = '''
SELECT no_cliente, pais, Language

FROM cliente
LEFT JOIN idiomas
ON cliente.pais = idiomas.Name
WHERE Language IS null
'''

pd.read_sql(query, conn)
# Out:
#     no_cliente pais Language
# 0          363  USA     None
# 1          181  USA     None
# 2          131  USA     None
# 3          486  USA     None
# 4          187   UK     None
# 5          129  USA     None
# 6          124  USA     None
# 7          424  USA     None
# 8          112  USA     None
# 9          151  USA     None
# 10         324   UK     None
# 11         198  USA     None
# 12         447  USA     None
# 13         161  USA     None
# 14         320  USA     None
# 15         205  USA     None
# 16         379  USA     None
# 17         487  USA     None
# 18         219  USA     None
# 19         321  USA     None
# 20         347  USA     None
# 21         462  USA     None
# 22         175  USA     None
# 23         339  USA     None
# 24         489   UK     None
# 25         319  USA     None
# 26         455  USA     None
# 27         475  USA     None
# 28         495  USA     None
# 29         239  USA     None
# 30         173  USA     None
# 31         240   UK     None
# 32         328  USA     None
# 33         456  USA     None
# 34         450  USA     None
# 35         201   UK     None
# 36         362  USA     None
# 37         157  USA     None
# 38         204  USA     None
# 39         286  USA     None

# %%
# Observamos que hay clientes (de USA y UK) que no tienen idioma asociado. Comprobamos que se debe a que en la base de datos
# world, los nombres de estos países no coinciden

query= '''
SELECT * 
FROM idiomas
WHERE Name LIKE '%United%'
'''

pd.read_sql(query, conn)
# Out:
#                                    Name Language IsOfficial  Percentage
# 0                  United Arab Emirates   Arabic          T        42.0
# 1                        United Kingdom  English          T        97.3
# 2  United States Minor Outlying Islands  English          T         0.0
# 3                         United States  English          T        86.2

# %%
# Modifico la tabla idiomas
query = '''
SELECT  CASE WHEN Name="United States" THEN "USA"
             WHEN Name = "United Kingdom" THEN "UK"
             ELSE Name END AS Name,
        Language,
        IsOfficial,
        Percentage

FROM CountryLanguage
JOIN Country
ON CountryLanguage.CountryCode = Country.Code

WHERE Percentage = (SELECT MAX(Percentage) 
                        FROM CountryLanguage
                        WHERE Country.Code = CountryLanguage.CountryCode
                    )
'''

idiomas = pd.read_sql(query, db)
idiomas
# Out:
#              Name        Language IsOfficial  Percentage
# 0           Aruba      Papiamento          F        76.7
# 1     Afghanistan          Pashto          T        52.4
# 2          Angola       Ovimbundu          F        37.2
# 3        Anguilla         English          T         0.0
# 4         Albania       Albaniana          T        97.9
# ..            ...             ...        ...         ...
# 236         Yemen          Arabic          T        99.6
# 237    Yugoslavia  Serbo-Croatian          T        75.2
# 238  South Africa            Zulu          T        22.7
# 239        Zambia           Bemba          F        29.7
# 240      Zimbabwe           Shona          F        72.1
#
# [241 rows x 4 columns]

# %%
idiomas.to_sql('idiomas', conn, index=False, if_exists='replace')

# %%
# Relacionar a cada cliente con su idioma
query = '''
SELECT no_cliente, pais, Language

FROM cliente
LEFT JOIN idiomas
ON cliente.pais = idiomas.Name
'''

idiomas_cliente = pd.read_sql(query, conn)

# %%
pd.set_option('display.max_rows',100)
idiomas_cliente
# Out:
#     no_cliente         pais        Language
# 0          363          USA         English
# 1          128      Germany          German
# 2          181          USA         English
# 3          121       Norway       Norwegian
# 4          141        Spain         Spanish
# 5          145      Denmark          Danish
# 6          278        Italy         Italian
# 7          131          USA         English
# 8          385  Philippines        Pilipino
# 9          486          USA         English
# 10         187           UK         English
# 11         129          USA         English
# 12         144       Sweden         Swedish
# 13         124          USA         English
# 14         172       France          French
# 15         424          USA         English
# 16         381      Belgium           Dutch
# 17         148    Singapore         Chinese
# 18         216        Spain         Spanish
# 19         382      Austria          German
# 20         114    Australia         English
# 21         353       France          French
# 22         350       France          French
# 23         103       France          French
# 24         112          USA         English
# 25         458        Spain         Spanish
# 26         151          USA         English
# 27         324           UK         English
# 28         198          USA         English
# 29         447          USA         English
# 30         323  New Zealand         English
# 31         250       France          French
# 32         242       France          French
# 33         496  New Zealand         English
# 34         282    Australia         English
# 35         161          USA         English
# 36         334      Finland         Finnish
# 37         320          USA         English
# 38         205          USA         English
# 39         379          USA         English
# 40         276    Australia         English
# 41         487          USA         English
# 42         311      Finland         Finnish
# 43         333    Australia         English
# 44         219          USA         English
# 45         186      Finland         Finnish
# 46         473        Italy         Italian
# 47         321          USA         English
# 48         347          USA         English
# 49         227      Denmark          Danish
# 50         452      Austria          German
# 51         462          USA         English
# 52         448       Sweden         Swedish
# 53         233       Canada         English
# 54         175          USA         English
# 55         386        Italy         Italian
# 56         344        Spain         Spanish
# 57         171       France          French
# 58         167       Norway       Norwegian
# 59         339          USA         English
# 60         484        Spain         Spanish
# 61         489           UK         English
# 62         211    Hong Kong  Canton Chinese
# 63         259      Germany          German
# 64         471    Australia         English
# 65         146       France          French
# 66         319          USA         English
# 67         455          USA         English
# 68         475          USA         English
# 69         357  New Zealand         English
# 70         202       Canada         English
# 71         495          USA         English
# 72         177        Japan        Japanese
# 73         406       France          French
# 74         256       France          French
# 75         166    Singapore         Chinese
# 76         189      Ireland         English
# 77         314      Belgium           Dutch
# 78         239          USA         English
# 79         298  Switzerland          German
# 80         173          USA         English
# 81         240           UK         English
# 82         328          USA         English
# 83         412  New Zealand         English
# 84         260       Canada         English
# 85         209       France          French
# 86         456          USA         English
# 87         450          USA         English
# 88         201           UK         English
# 89         398        Japan        Japanese
# 90         362          USA         English
# 91         157          USA         English
# 92         119       France          French
# 93         204          USA         English
# 94         249        Italy         Italian
# 95         299       Norway       Norwegian
# 96         286          USA         English
# 97         415      Germany          German

# %%
idiomas_cliente.to_sql('idiomas_cliente',conn, index=False, if_exists='replace')

# %%
pd.read_sql('SELECT name FROM sqlite_master WHERE type="table"',conn)
# Out:
#               name
# 0          cliente
# 1         producto
# 2          compras
# 3          idiomas
# 4  idiomas_cliente

# %% [markdown]
#  Puedes generar el diagrama de la base de datos en https://dbdiagram.io/d
#  <img src="https://i.ibb.co/4PXndfB/Ejercicio2.png">

# %% [markdown]
# ¿Cuál es el producto que aporta más beneficios?

# %%
query ='''
SELECT nombre_producto, SUM(cantidad_orden*(precio_cada-precio_compra)) AS Beneficio

FROM compras
JOIN producto
ON compras.codigo_producto = producto.codigo_producto

GROUP BY nombre_producto
ORDER BY Beneficio DESC
'''

pd.read_sql(query, conn)
# Out:
#                           nombre_producto  Beneficio
# 0             1992 Ferrari 360 Spider red  135996.78
# 1                1952 Alpine Renault 1300   95282.58
# 2                       2001 Ferrari Enzo   93349.65
# 3    2003 Harley-Davidson Eagle Drag Bike   81031.30
# 4                       1968 Ford Mustang   72579.26
# ..                                    ...        ...
# 104          1930 Buick Marquette Phaeton   12536.80
# 105      1936 Mercedes Benz 500k Roadster   11841.39
# 106                     1982 Ducati 996 R   11397.92
# 107                      Boeing X-32A JSF   11233.33
# 108           1939 Chevrolet Deluxe Coupe    6904.85
#
# [109 rows x 2 columns]
